# %% [markdown]
# # **CompaniesMarketCap.com**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from csv import writer

# Definizione del dataframe
df = pd.DataFrame(columns=['Name', 'Symbol','MarketCap',  'Price', 'Country'])

i = 1 #variabile da incrementare per scorrere le pagine dell'url del sito

#scorriamo le prime 10 pagine del sito
while i < 11:

  j = str(i)    #la variabile va convertita in stringa per essere passata nell'url
  link = 'https://companiesmarketcap.com/page/'+j+'/'
  print(link)

  data = requests.get(link).text

  soup = BeautifulSoup(data, 'html.parser')

  # Troviamo le tabelle e le classi
  print('Classes of each table:')
  for table in soup.find_all('table'):
      print(table.get('class'))

  # Troviamo tutte le righe
  for row in table.tbody.find_all('tr'):    #scorre le righe
      # Troviamo le colonne
      columns = row.find_all('td')    #scorre i dati della tabella
    
      if(columns != []):
          name = row.find('div', class_="company-name").text.replace('\n', '')
          symbol = row.find('div', class_='company-code').text.replace('\n', '')
          mcap = columns[2].text.strip()
          price = columns[3].text.strip()
          country = columns[6].text[3:].strip()

          df = df.append({'Name': name, 'Symbol' : symbol, 'MarketCap': mcap, 'Price': price, 'Country': country}, ignore_index=True)

  del link
  i = i+1

df.head(None)   #stampa la tabella [senza (None) stampa solo le prime 5 righe]

df.to_excel("companiesCMP.xls")    #probabilmente formato migliore per salvarlo
# Out:
# https://companiesmarketcap.com/page/1/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/2/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/3/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/4/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/5/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/6/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/7/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/8/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/9/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# https://companiesmarketcap.com/page/10/
# Classes of each table:
# ['default-table', 'table', 'marketcap-table', 'dataTable']
# <ipython-input-1-8f65e2ea60a9>:46: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("companiesCMP.xls")    #probabilmente formato migliore per salvarlo

# %% [markdown]
# # **Forbes.com**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from csv import writer

# Definizione del dataframe
df = pd.DataFrame(columns=['Name', 'Country', 'Sales',  'Profit', 'Assets', 'Market Value'])

link = 'https://www.forbes.com/lists/global2000/'
print(link)

data = requests.get(link).text

soup = BeautifulSoup(data, 'html.parser')

# Troviamo le tabelle e le classi
print('Classes of each table:')
for table in soup.find_all("a", {"class": "table-row"}):    #A quanto pare questo for è fondamentale perchè definisce l'elemento 'table'
    print(table.get('class'))

# Creiamo una lista
tables = soup.find_all("a", {"class": "table-row"})

i = 0
# Collecting Ddata
for row in tables:    #scorre le righe
    # Find all data for each column
    columns = row.find_all('div')    #scorre i dati della tabella
    
    if(columns != []):
        name = columns[1].text.strip()
        country = columns[2].text.strip()
        sales = columns[3].text.strip()
        profit = columns[4].text.strip()
        assets = columns[5].text.strip()
        mvalue = columns[6].text.strip()

        df = df.append({'Name': name, 'Country' : country, 'Sales': sales, 'Profit': profit, 'Assets': assets, 'Market Value': mvalue}, ignore_index=True)
    
    i = i+1
    if(i>999): #Ci bastano 1000 elementi
      break

df.head
df.to_excel("companiesForbes.xls")
# Out:
# https://www.forbes.com/lists/global2000/
# Classes of each table:
# ['table-row', 'active', 'premiumProfile-berkshire-hathaway']
# ['table-row', 'active', 'premiumProfile-icbc']
# ['table-row', 'active', 'premiumProfile-saudi-arabian-oil-company-saudi-aramco']
# ['table-row', 'active', 'premiumProfile-jpmorgan-chase']
# ['table-row', 'active', 'premiumProfile-china-construction-bank']
# ['table-row', 'active', 'premiumProfile-amazon']
# ['table-row', 'active', 'premiumProfile-apple']
# ['table-row', 'active', 'premiumProfile-agricultural-bank-of-china']
# ['table-row', 'active', 'premiumProfile-bank-of-america']
# ['table-row', 'active', 'premiumProfile-toyota-motor']
# ['table-row', 'active', 'premiumProfile-alphabet']
# ['table-row', 'active', 'premiumProfile-microsoft']
# ['table-row', 'active', 'premiumProfile-bank-of-china']
# ['table-row', 'active', 'premiumProfile-samsung-electronics']
# ['table-row', 'active', 'premiumProfile-exxon-mobil']
# ['table-row', 'active', 'premiumProfile-shell']
# ['table-row', 'active', 'premiumProfile-ping-an-insurance']
# ['table-row', 'active', 'premiumProfile-wells-fargo']
# ['table-row', 'active', 'premiumProfile-verizon-communications']
# ['table-row', 'active', 'premiumProfile-att']
# ['table-row', 'active', 'premiumProfile-petrochina']
# ['table-row', 'active', 'premiumProfile-unitedhealth-group']
# ['table-row', 'active', 'premiumProfile-walmart']
# ['table-row', 'active', 'premiumProfile-china-merchants-bank']
# ['table-row', 'active', 'premiumProfile-volkswagen-group']
# ['table-row', 'active', 'premiumProfile-chevron']
# ['table-row', 'active', 'premiumProfile-citigroup']
# ['table-row', 'active', 'premiumProfile-tencent-holdings']
# ['table-row', 'active', 'premiumProfile-total']
# ['table-row', 'active', 'premiumProfile-postal-savings-bank-of-china']
# ['table-row', 'active', 'premiumProfile-china-mobile']
# ['table-row', 'active', 'premiumProfile-comcast']
# ['table-row', 'active', 'premiumProfile-alibaba-group']
# ['table-row', 'active', 'premiumProfile-meta-platforms']
# ['table-row', 'active', 'premiumProfile-allianz']
# ['table-row', 'active', 'premiumProfile-morgan-stanley']
# ['table-row', 'active', 'premiumProfile-goldman-sachs-group']
# ['table-row', 'active', 'premiumProfile-hsbc-holdings']
# ['table-row', 'active', 'premiumProfile-bnp-paribas']
# ['table-row', 'active', 'premiumProfile-johnson-johnson']
# ['table-row', 'active', 'premiumProfile-mercedes-benz-group']
# ['table-row', 'active', 'premiumProfile-cvs-health']
# ['table-row', 'active', 'premiumProfile', 'premiumProfile-pfizer']
# ['table-row', 'active', 'premiumProfile-softbank']
# ['table-row', 'active', 'premiumProfile-sinopec']
# ['table-row', 'active', 'premiumProfile-rbc']
# ['table-row', 'active', 'premiumProfile-nestle']
# ['table-row', 'active', 'premiumProfile-axa-group']
# ['table-row', 'active', 'premiumProfile-gazprom']
# ['table-row', 'active', 'premiumProfile-bp']
# ['table-row', 'active', 'premiumProfile-intel']
# ['table-row', 'active', 'premiumProfile-td-bank-group']
# ['table-row', 'active', 'premiumProfile-nippon-tel-tel']
# ['table-row', 'active', 'premiumProfile-reliance-industries']
# ['table-row', 'active', 'premiumProfile-industrial-bank']
# ['table-row', 'active', 'premiumProfile-sony']
# ['table-row', 'active', 'premiumProfile-santander']
# ['table-row', 'active', 'premiumProfile-mitsubishi-ufj-financial']
# ['table-row', 'active', 'premiumProfile-taiwan-semiconductor']
# ['table-row', 'active', 'premiumProfile-ford-motor']
# ['table-row', 'active', 'premiumProfile-lvmh-moet-hennessy-louis-vuitton']
# ['table-row', 'active', 'premiumProfile-bank-of-communications']
# ['table-row', 'active', 'premiumProfile-procter-gamble']
# ['table-row', 'active', 'premiumProfile-bmw-group']
# ['table-row', 'active', 'premiumProfile-petrobras']
# ['table-row', 'active', 'premiumProfile-deutsche-telekom']
# ['table-row', 'active', 'premiumProfile-abbvie']
# ['table-row', 'active', 'premiumProfile-novartis']
# ['table-row', 'active', 'premiumProfile-general-motors']
# ['table-row', 'active', 'premiumProfile-equinor']
# ['table-row', 'active', 'premiumProfile-china-life-insurance']
# ['table-row', 'active', 'premiumProfile-roche-holding']
# ['table-row', 'active', 'premiumProfile-aia-group']
# ['table-row', 'active', 'premiumProfile-metlife']
# ['table-row', 'active', 'premiumProfile-bhp-group-ltd']
# ['table-row', 'active', 'premiumProfile', 'premiumProfile-the-home-depot']
# ['table-row', 'active', 'premiumProfile-american-express']
# ['table-row', 'active', 'premiumProfile', 'premiumProfile-siemens']
# ['table-row', 'active', 'premiumProfile-stellantis']
# ['table-row', 'active', 'premiumProfile-zurich-insurance-group']
# ['table-row', 'active', 'premiumProfile-rosneft']
# ['table-row', 'active', 'premiumProfile-rio-tinto']
# ['table-row', 'active', 'premiumProfile-brookfield-asset-management']
# ['table-row', 'active', 'premiumProfile-cigna']
# ['table-row', 'active', 'premiumProfile-prudential-financial']
# ['table-row', 'active', 'premiumProfile-pepsico']
# ['table-row', 'active', 'premiumProfile-merck-co']
# ['table-row', 'active', 'premiumProfile-elevance-health']
# ['table-row', 'active', 'premiumProfile-bank-of-nova-scotia']
# ['table-row', 'active', 'premiumProfile-american-international-group']
# ['table-row', 'active', 'premiumProfile-glencore-international']
# ['table-row', 'active', 'premiumProfile-cisco-systems']
# ['table-row', 'active', 'premiumProfile-anheuser-busch-inbev']
# ['table-row', 'active', 'premiumProfile-walt-disney']
# ['table-row', 'active', 'premiumProfile-chubb']
# ['table-row', 'active', 'premiumProfile-citic']
# ['table-row', 'active', 'premiumProfile-lloyds-banking-group']
# ['table-row', 'active', 'premiumProfile-ibm']
# ['table-row', 'active', 'premiumProfile-sanofi']
# ['table-row', 'active', 'premiumProfile-united-parcel-service']
# ['table-row', 'active', 'premiumProfile-british-american-tobacco']
# ['table-row', 'active', 'premiumProfile-ubs']
# ['table-row', 'active', 'premiumProfile-honda-motor']
# ['table-row', 'active', 'premiumProfile-mitsubishi']
# ['table-row', 'active', 'premiumProfile-china-state-construction-engineering']
# ['table-row', 'active', 'premiumProfile-state-bank-of-india']
# ['table-row', 'active', 'premiumProfile-commonwealth-bank']
# ['table-row', 'active', 'premiumProfile-shanghai-pudong-development']
# ['table-row', 'active', 'premiumProfile-raytheon-technologies']
# ['table-row', 'active', 'premiumProfile-enel']
# ['table-row', 'active', 'premiumProfile-eni']
# ['table-row', 'active', 'premiumProfile-capital-one']
# ['table-row', 'active', 'premiumProfile-bristol-myers-squibb']
# ['table-row', 'active', 'premiumProfile-coca-cola']
# ['table-row', 'active', 'premiumProfile-oracle']
# ['table-row', 'active', 'premiumProfile-sberbank']
# ['table-row', 'active', 'premiumProfile-bank-of-montreal']
# ['table-row', 'active', 'premiumProfile-vale']
# ['table-row', 'active', 'premiumProfile-edf']
# ['table-row', 'active', 'premiumProfile-thermo-fisher-scientific']
# ['table-row', 'active', 'premiumProfile-credit-agricole']
# ['table-row', 'active', 'premiumProfile-airbus']
# ['table-row', 'active', 'premiumProfile-costco-wholesale']
# ['table-row', 'active', 'premiumProfile-hon-hai-precision']
# ['table-row', 'active', 'premiumProfile-unilever']
# ['table-row', 'active', 'premiumProfile-charter-communications']
# ['table-row', 'active', 'premiumProfile-sumitomo-mitsui-financial']
# ['table-row', 'active', 'premiumProfile-conocophillips']
# ['table-row', 'active', 'premiumProfile-glaxosmithkline']
# ['table-row', 'active', 'premiumProfile-intesa-sanpaolo']
# ['table-row', 'active', 'premiumProfile-manulife']
# ['table-row', 'active', 'premiumProfile-us-bancorp']
# ['table-row', 'active', 'premiumProfile-basf']
# ['table-row', 'active', 'premiumProfile-cnooc']
# ['table-row', 'active', 'premiumProfile-abbott-laboratories']
# ['table-row', 'active', 'premiumProfile-iberdrola']
# ['table-row', 'active', 'premiumProfile-china-shenhua-energy']
# ['table-row', 'active', 'premiumProfile-itau-unibanco-holding']
# ['table-row', 'active', 'premiumProfile-caterpillar']
# ['table-row', 'active', 'premiumProfile-mitsui']
# ['table-row', 'active', 'premiumProfile-itochu']
# ['table-row', 'active', 'premiumProfile-charles-schwab']
# ['table-row', 'active', 'premiumProfile-truist-financial']
# ['table-row', 'active', 'premiumProfile-enbridge']
# ['table-row', 'active', 'premiumProfile-hitachi']
# ['table-row', 'active', 'premiumProfile-kddi']
# ['table-row', 'active', 'premiumProfile-hyundai-motor']
# ['table-row', 'active', 'premiumProfile-china-citic-bank']
# ['table-row', 'active', 'premiumProfile-visa']
# ['table-row', 'active', 'premiumProfile-target']
# ['table-row', 'active', 'premiumProfile-bbva-banco-bilbao-vizcaya']
# ['table-row', 'active', 'premiumProfile-tesla']
# ['table-row', 'active', 'premiumProfile-john-deere']
# ['table-row', 'active', 'premiumProfile-hdfc-bank']
# ['table-row', 'active', 'premiumProfile-barclays']
# ['table-row', 'active', 'premiumProfile-munich-re']
# ['table-row', 'active', 'premiumProfile-japan-post-holdings']
# ['table-row', 'active', 'premiumProfile-walgreens']
# ['table-row', 'active', 'premiumProfile-danaher']
# ['table-row', 'active', 'premiumProfile-generali-group']
# ['table-row', 'active', 'premiumProfile-moller-maersk']
# ['table-row', 'active', 'premiumProfile-lowes']
# ['table-row', 'active', 'premiumProfile-fedex']
# ['table-row', 'active', 'premiumProfile-deutsche-post']
# ['table-row', 'active', 'premiumProfile-pnc-financial-services']
# ['table-row', 'active', 'premiumProfile-broadcom']
# ['table-row', 'active', 'premiumProfile-lukoil']
# ['table-row', 'active', 'premiumProfile-medtronic']
# ['table-row', 'active', 'premiumProfile-sap']
# ['table-row', 'active', 'premiumProfile-sk-hynix']
# ['table-row', 'active', 'premiumProfile-engie']
# ['table-row', 'active', 'premiumProfile-lockheed-martin']
# ['table-row', 'active', 'premiumProfile-blackrock']
# ['table-row', 'active', 'premiumProfile-westpac-banking']
# ['table-row', 'active', 'premiumProfile-duke-energy']
# ['table-row', 'active', 'premiumProfile-dell-technologies']
# ['table-row', 'active', 'premiumProfile-vinci']
# ['table-row', 'active', 'premiumProfile-tokio-marine-holdings']
# ['table-row', 'active', 'premiumProfile-america-movil']
# ['table-row', 'active', 'premiumProfile-eon']
# ['table-row', 'active', 'premiumProfile-anglo-american']
# ['table-row', 'active', 'premiumProfile-banco-bradesco']
# ['table-row', 'active', 'premiumProfile-ing-group']
# ['table-row', 'active', 'premiumProfile-accenture']
# ['table-row', 'active', 'premiumProfile-honeywell-international']
# ['table-row', 'active', 'premiumProfile-mizuho-financial']
# ['table-row', 'active', 'premiumProfile-linde']
# ['table-row', 'active', 'premiumProfile-arcelormittal']
# ['table-row', 'active', 'premiumProfile-canadian-imperial-bank']
# ['table-row', 'active', 'premiumProfile-poly-developments-holdings-group']
# ['table-row', 'active', 'premiumProfile-micron-technology']
# ['table-row', 'active', 'premiumProfile-anz']
# ['table-row', 'active', 'premiumProfile-fubon-financial']
# ['table-row', 'active', 'premiumProfile-china-telecom']
# ['table-row', 'active', 'premiumProfile-hca-healthcare']
# ['table-row', 'active', 'premiumProfile-dow']
# ['table-row', 'active', 'premiumProfile-telefonica']
# ['table-row', 'active', 'premiumProfile-china-vanke']
# ['table-row', 'active', 'premiumProfile-national-australia-bank']
# ['table-row', 'active', 'premiumProfile-cathay-financial']
# ['table-row', 'active', 'premiumProfile-qualcomm']
# ['table-row', 'active', 'premiumProfile-loreal']
# ['table-row', 'active', 'premiumProfile-allstate']
# ['table-row', 'active', 'premiumProfile-saic-motor']
# ['table-row', 'active', 'premiumProfile-icici-bank']
# ['table-row', 'active', 'premiumProfile-china-everbright-bank']
# ['table-row', 'active', 'premiumProfile-gilead-sciences']
# ['table-row', 'active', 'premiumProfile-china-pacific-insurance']
# ['table-row', 'active', 'premiumProfile-nvidia']
# ['table-row', 'active', 'premiumProfile-amgen']
# ['table-row', 'active', 'premiumProfile-union-pacific']
# ['table-row', 'active', 'premiumProfile-dai-ichi-life-insurance']
# ['table-row', 'active', 'premiumProfile-nike']
# ['table-row', 'active', 'premiumProfile-takeda-pharmaceutical']
# ['table-row', 'active', 'premiumProfile-philip-morris-international']
# ['table-row', 'active', 'premiumProfile-paypal']
# ['table-row', 'active', 'premiumProfile-china-resources-land']
# ['table-row', 'active', 'premiumProfile-oversea-chinese-banking']
# ['table-row', 'active', 'premiumProfile-midea-group']
# ['table-row', 'active', 'premiumProfile-travelers']
# ['table-row', 'active', 'premiumProfile-eli-lilly']
# ['table-row', 'active', 'premiumProfile-mondelez-international']
# ['table-row', 'active', 'premiumProfile-mcdonalds']
# ['table-row', 'active', 'premiumProfile-general-electric']
# ['table-row', 'active', 'premiumProfile-societe-generale']
# ['table-row', 'active', 'premiumProfile-schneider-electric']
# ['table-row', 'active', 'premiumProfile-3m']
# ['table-row', 'active', 'premiumProfile-aflac']
# ['table-row', 'active', 'premiumProfile-oil-natural-gas']
# ['table-row', 'active', 'premiumProfile-southern-company']
# ['table-row', 'active', 'premiumProfile-deutsche-bank']
# ['table-row', 'active', 'premiumProfile-ptt']
# ['table-row', 'active', 'premiumProfile-ck-hutchison']
# ['table-row', 'active', 'premiumProfile-canadian-natural-resources']
# ['table-row', 'active', 'premiumProfile-sun-life-financial']
# ['table-row', 'active', 'premiumProfile-northrop-grumman']
# ['table-row', 'active', 'premiumProfile-archer-daniels-midland']
# ['table-row', 'active', 'premiumProfile-marathon-petroleum']
# ['table-row', 'active', 'premiumProfile-china-minsheng-bank']
# ['table-row', 'active', 'premiumProfile-legal-general-group']
# ['table-row', 'active', 'premiumProfile-netflix']
# ['table-row', 'active', 'premiumProfile-progressive']
# ['table-row', 'active', 'premiumProfile-longfor-group-holdings']
# ['table-row', 'active', 'premiumProfile-dbs']
# ['table-row', 'active', 'premiumProfile-cosco-shipping']
# ['table-row', 'active', 'premiumProfile-china-communications-construction']
# ['table-row', 'active', 'premiumProfile-natwest-group']
# ['table-row', 'active', 'premiumProfile-exelon']
# ['table-row', 'active', 'premiumProfile-humana']
# ['table-row', 'active', 'premiumProfile-general-dynamics']
# ['table-row', 'active', 'premiumProfile-power-corp-of-canada']
# ['table-row', 'active', 'premiumProfile-qatar-national-bank']
# ['table-row', 'active', 'premiumProfile-bayer']
# ['table-row', 'active', 'premiumProfile-kkr']
# ['table-row', 'active', 'premiumProfile-country-garden-holdings']
# ['table-row', 'active', 'premiumProfile-nextera-energy']
# ['table-row', 'active', 'premiumProfile-kb-financial-group']
# ['table-row', 'active', 'premiumProfile-china-railway-group']
# ['table-row', 'active', 'premiumProfile-hp']
# ['table-row', 'active', 'premiumProfile-nordea-bank']
# ['table-row', 'active', 'premiumProfile-seven-i-holdings']
# ['table-row', 'active', 'premiumProfile-suncor-energy']
# ['table-row', 'active', 'premiumProfile-salesforce']
# ['table-row', 'active', 'premiumProfile-air-liquide']
# ['table-row', 'active', 'premiumProfile-denso']
# ['table-row', 'active', 'premiumProfile-bank-of-ny-mellon']
# ['table-row', 'active', 'premiumProfile-mastercard']
# ['table-row', 'active', 'premiumProfile-banco-do-brasil']
# ['table-row', 'active', 'premiumProfile-centene']
# ['table-row', 'active', 'premiumProfile-hdfc']
# ['table-row', 'active', 'premiumProfile-freeport-mcmoran']
# ['table-row', 'active', 'premiumProfile-merck-kgaa-germany']
# ['table-row', 'active', 'premiumProfile-caixabank']
# ['table-row', 'active', 'premiumProfile-abb']
# ['table-row', 'active', 'premiumProfile-volvo-group']
# ['table-row', 'active', 'premiumProfile-occidental-petroleum']
# ['table-row', 'active', 'premiumProfile-national-grid']
# ['table-row', 'active', 'premiumProfile-mckesson']
# ['table-row', 'active', 'premiumProfile-shinhan-financial-group']
# ['table-row', 'active', 'premiumProfile-asml-holding']
# ['table-row', 'active', 'premiumProfile-nutrien']
# ['table-row', 'active', 'premiumProfile-investor-ab']
# ['table-row', 'active', 'premiumProfile-kia']
# ['table-row', 'active', 'premiumProfile-saint-gobain']
# ['table-row', 'active', 'premiumProfile-novo-nordisk']
# ['table-row', 'active', 'premiumProfile-posco']
# ['table-row', 'active', 'premiumProfile-diageo']
# ['table-row', 'active', 'premiumProfile-royal-ahold-delhaize']
# ['table-row', 'active', 'premiumProfile-picc']
# ['table-row', 'active', 'premiumProfile-dominion-energy']
# ['table-row', 'active', 'premiumProfile-kroger']
# ['table-row', 'active', 'premiumProfile-baoshan-iron-steel']
# ['table-row', 'active', 'premiumProfile-kweichow-moutai']
# ['table-row', 'active', 'premiumProfile-xiaomi']
# ['table-row', 'active', 'premiumProfile-bank-of-ningbo']
# ['table-row', 'active', 'premiumProfile-ecopetrol']
# ['table-row', 'active', 'premiumProfile-lyondellbasell-industries']
# ['table-row', 'active', 'premiumProfile-contemporary-amperex-technology']
# ['table-row', 'active', 'premiumProfile-unicredit']
# ['table-row', 'active', 'premiumProfile-amerisourcebergen']
# ['table-row', 'active', 'premiumProfile-essilorluxottica']
# ['table-row', 'active', 'premiumProfile-inditex']
# ['table-row', 'active', 'premiumProfile-starbucks']
# ['table-row', 'active', 'premiumProfile-nucor']
# ['table-row', 'active', 'premiumProfile-intercontinentalexchange']
# ['table-row', 'active', 'premiumProfile-tjx-cos']
# ['table-row', 'active', 'premiumProfile-kbc-group']
# ['table-row', 'active', 'premiumProfile-tesco']
# ['table-row', 'active', 'premiumProfile-boe-technology-group']
# ['table-row', 'active', 'premiumProfile-blackstone']
# ['table-row', 'active', 'premiumProfile-american-electric']
# ['table-row', 'active', 'premiumProfile-macquarie-group']
# ['table-row', 'active', 'premiumProfile-marubeni']
# ['table-row', 'active', 'premiumProfile-swiss-re']
# ['table-row', 'active', 'premiumProfile-eog-resources']
# ['table-row', 'active', 'premiumProfile-cnp-assurances']
# ['table-row', 'active', 'premiumProfile-automatic-data-processing']
# ['table-row', 'active', 'premiumProfile-phillips-66']
# ['table-row', 'active', 'premiumProfile-tyson-foods']
# ['table-row', 'active', 'premiumProfile-repsol']
# ['table-row', 'active', 'premiumProfile-sumitomo']
# ['table-row', 'active', 'premiumProfile-holcim']
# ['table-row', 'active', 'premiumProfile-altria-group']
# ['table-row', 'active', 'premiumProfile-applied-materials']
# ['table-row', 'active', 'premiumProfile-daimler-truck-holding']
# ['table-row', 'active', 'premiumProfile-zijin-mining-group']
# ['table-row', 'active', 'premiumProfile-saudi-national-bank']
# ['table-row', 'active', 'premiumProfile-richemont']
# ['table-row', 'active', 'premiumProfile-kering']
# ['table-row', 'active', 'premiumProfile-saudi-electricity']
# ['table-row', 'active', 'premiumProfile-danone']
# ['table-row', 'active', 'premiumProfile-nippon-steel']
# ['table-row', 'active', 'premiumProfile-lg-chem']
# ['table-row', 'active', 'premiumProfile-discover-financial-services']
# ['table-row', 'active', 'premiumProfile-couche-tard']
# ['table-row', 'active', 'premiumProfile-huaxia-bank']
# ['table-row', 'active', 'premiumProfile-nn-group']
# ['table-row', 'active', 'premiumProfile-fannie-mae']
# ['table-row', 'active', 'premiumProfile-fresenius']
# ['table-row', 'active', 'premiumProfile-marsh-mclennan']
# ['table-row', 'active', 'premiumProfile-ameriprise-financial']
# ['table-row', 'active', 'premiumProfile-becton-dickinson']
# ['table-row', 'active', 'premiumProfile-panasonic']
# ['table-row', 'active', 'premiumProfile-msad-insurance']
# ['table-row', 'active', 'premiumProfile-orix']
# ['table-row', 'active', 'premiumProfile-citic-securities']
# ['table-row', 'active', 'premiumProfile-first-abu-dhabi-bank']
# ['table-row', 'active', 'premiumProfile-bce']
# ['table-row', 'active', 'premiumProfile-schlumberger']
# ['table-row', 'active', 'premiumProfile-texas-instruments']
# ['table-row', 'active', 'premiumProfile-bank-rakyat-indonesia']
# ['table-row', 'active', 'premiumProfile-standard-chartered']
# ['table-row', 'active', 'premiumProfile-crh']
# ['table-row', 'active', 'premiumProfile-bank-of-beijing']
# ['table-row', 'active', 'premiumProfile-paramount']
# ['table-row', 'active', 'premiumProfile-bank-of-jiangsu']
# ['table-row', 'active', 'premiumProfile-dupont-de-nemours']
# ['table-row', 'active', 'premiumProfile-gree-electric-appliances']
# ['table-row', 'active', 'premiumProfile-indian-oil']
# ['table-row', 'active', 'premiumProfile-dollar-general']
# ['table-row', 'active', 'premiumProfile-kraft-heinz-company']
# ['table-row', 'active', 'premiumProfile-wilmar-international']
# ['table-row', 'active', 'premiumProfile-freddie-mac']
# ['table-row', 'active', 'premiumProfile-hewlett-packard-enterprise']
# ['table-row', 'active', 'premiumProfile-japan-tobacco']
# ['table-row', 'active', 'premiumProfile-poste-italiane']
# ['table-row', 'active', 'premiumProfile-united-overseas-bank']
# ['table-row', 'active', 'premiumProfile-china-unicom']
# ['table-row', 'active', 'premiumProfile-valero-energy']
# ['table-row', 'active', 'premiumProfile-csx']
# ['table-row', 'active', 'premiumProfile-danske-bank']
# ['table-row', 'active', 'premiumProfile-fortescue-metals-group']
# ['table-row', 'active', 'premiumProfile-china-railway-construction']
# ['table-row', 'active', 'premiumProfile-moderna']
# ['table-row', 'active', 'premiumProfile-woolworths']
# ['table-row', 'active', 'premiumProfile-anhui-conch-cement']
# ['table-row', 'active', 'premiumProfile-adobe']
# ['table-row', 'active', 'premiumProfile-hartford-financial-services']
# ['table-row', 'active', 'premiumProfile-state-street']
# ['table-row', 'active', 'premiumProfile-al-rajhi-bank']
# ['table-row', 'active', 'premiumProfile-power-construction-corporation-of-china']
# ['table-row', 'active', 'premiumProfile-shin-etsu-chemical']
# ['table-row', 'active', 'premiumProfile-fiserv']
# ['table-row', 'active', 'premiumProfile-regeneron-pharmaceuticals']
# ['table-row', 'active', 'premiumProfile-eneos-holdings']
# ['table-row', 'active', 'premiumProfile-tata-consultancy-services']
# ['table-row', 'active', 'premiumProfile-sompo']
# ['table-row', 'active', 'premiumProfile-omv-group']
# ['table-row', 'active', 'premiumProfile-swiss-life-holding']
# ['table-row', 'active', 'premiumProfile-bank-of-shanghai']
# ['table-row', 'active', 'premiumProfile-american-tower']
# ['table-row', 'active', 'premiumProfile-pioneer-natural-resources']
# ['table-row', 'active', 'premiumProfile-sun-hung-kai-properties']
# ['table-row', 'active', 'premiumProfile-wanhua-chemical-group']
# ['table-row', 'active', 'premiumProfile-sampo']
# ['table-row', 'active', 'premiumProfile-china-merchants-shekou-industrial-zone-holdings']
# ['table-row', 'active', 'premiumProfile-haier-smart-home']
# ['table-row', 'active', 'premiumProfile-eaton']
# ['table-row', 'active', 'premiumProfile-sk']
# ['table-row', 'active', 'premiumProfile-johnson-controls-international']
# ['table-row', 'active', 'premiumProfile-jbs']
# ['table-row', 'active', 'premiumProfile-saudi-telecom']
# ['table-row', 'active', 'premiumProfile-jardine-matheson']
# ['table-row', 'active', 'premiumProfile-canadian-national-railway']
# ['table-row', 'active', 'premiumProfile-stryker']
# ['table-row', 'active', 'premiumProfile-nokia']
# ['table-row', 'active', 'premiumProfile-mitsubishi-electric']
# ['table-row', 'active', 'premiumProfile-nissan-motor']
# ['table-row', 'active', 'premiumProfile-tata-steel']
# ['table-row', 'active', 'premiumProfile-heineken']
# ['table-row', 'active', 'premiumProfile-bae-systems']
# ['table-row', 'active', 'premiumProfile-etisalat']
# ['table-row', 'active', 'premiumProfile-bt-group']
# ['table-row', 'active', 'premiumProfile-ctbc-financial']
# ['table-row', 'active', 'premiumProfile-novatek']
# ['table-row', 'active', 'premiumProfile-greenland-holdings-group']
# ['table-row', 'active', 'premiumProfile-rwe-group']
# ['table-row', 'active', 'premiumProfile-daikin-industries']
# ['table-row', 'active', 'premiumProfile-aegon']
# ['table-row', 'active', 'premiumProfile-baidu']
# ['table-row', 'active', 'premiumProfile-ericsson']
# ['table-row', 'active', 'premiumProfile-canon']
# ['table-row', 'active', 'premiumProfile-lennar']
# ['table-row', 'active', 'premiumProfile-bank-of-nanjing']
# ['table-row', 'active', 'premiumProfile-philips']
# ['table-row', 'active', 'premiumProfile-keurig-dr-pepper']
# ['table-row', 'active', 'premiumProfile-china-yangtze-power']
# ['table-row', 'active', 'premiumProfile-dnb-bank']
# ['table-row', 'active', 'premiumProfile-emerson-electric']
# ['table-row', 'active', 'premiumProfile-imperial-brands']
# ['table-row', 'active', 'premiumProfile-boeing']
# ['table-row', 'active', 'premiumProfile-general-mills']
# ['table-row', 'active', 'premiumProfile-axis-bank']
# ['table-row', 'active', 'premiumProfile-national-bank-of-canada']
# ['table-row', 'active', 'premiumProfile-estee-lauder']
# ['table-row', 'active', 'premiumProfile-cnh-industrial']
# ['table-row', 'active', 'premiumProfile-fairfax-financial']
# ['table-row', 'active', 'premiumProfile-adidas']
# ['table-row', 'active', 'premiumProfile-michelin-group']
# ['table-row', 'active', 'premiumProfile-norfolk-southern']
# ['table-row', 'active', 'premiumProfile-principal-financial-group']
# ['table-row', 'active', 'premiumProfile-sempra']
# ['table-row', 'active', 'premiumProfile-fortum']
# ['table-row', 'active', 'premiumProfile-grupo-mexico']
# ['table-row', 'active', 'premiumProfile-dr-horton']
# ['table-row', 'active', 'premiumProfile-l3harris-technologies']
# ['table-row', 'active', 'premiumProfile-naspers']
# ['table-row', 'active', 'premiumProfile-standard-bank-group']
# ['table-row', 'active', 'premiumProfile-tc-energy']
# ['table-row', 'active', 'premiumProfile-norilsk-nickel']
# ['table-row', 'active', 'premiumProfile-naturgy-energy-group']
# ['table-row', 'active', 'premiumProfile', 'premiumProfile-waste-management']
# ['table-row', 'active', 'premiumProfile-henkel']
# ['table-row', 'active', 'premiumProfile-mediatek']
# ['table-row', 'active', 'premiumProfile-recruit-holdings']
# ['table-row', 'active', 'premiumProfile-hengli-petrochemical']
# ['table-row', 'active', 'premiumProfile-xcel-energy']
# ['table-row', 'active', 'premiumProfile-corteva']
# ['table-row', 'active', 'premiumProfile-synchrony-financial']
# ['table-row', 'active', 'premiumProfile-toyota-tsusho']
# ['table-row', 'active', 'premiumProfile-toyota-industries']
# ['table-row', 'active', 'premiumProfile-astrazeneca']
# ['table-row', 'active', 'premiumProfile-sunac-china-holdings']
# ['table-row', 'active', 'premiumProfile-china-evergrande-group']
# ['table-row', 'active', 'premiumProfile-bridgestone']
# ['table-row', 'active', 'premiumProfile-emirates-nbd']
# ['table-row', 'active', 'premiumProfile-daiwa-house-industry']
# ['table-row', 'active', 'premiumProfile-jd']
# ['table-row', 'active', 'premiumProfile-kinder-morgan']
# ['table-row', 'active', 'premiumProfile-china-national-building']
# ['table-row', 'active', 'premiumProfile', 'premiumProfile-fifth-third-bank']
# ['table-row', 'active', 'premiumProfile-firstrand']
# ['table-row', 'active', 'premiumProfile-carrefour']
# ['table-row', 'active', 'premiumProfile-fujitsu']
# ['table-row', 'active', 'premiumProfile-seb-ab']
# ['table-row', 'active', 'premiumProfile-surgutneftegas']
# ['table-row', 'active', 'premiumProfile-new-china-life-insurance']
# ['table-row', 'active', 'premiumProfile-barrick-gold']
# ['table-row', 'active', 'premiumProfile-dsv-panalpina']
# ['table-row', 'active', 'premiumProfile-talanx']
# ['table-row', 'active', 'premiumProfile-vodafone']
# ['table-row', 'active', 'premiumProfile-nintendo']
# ['table-row', 'active', 'premiumProfile-hana-financial']
# ['table-row', 'active', 'premiumProfile-hyundai-mobis']
# ['table-row', 'active', 'premiumProfile-ntpc']
# ['table-row', 'active', 'premiumProfile-maybank']
# ['table-row', 'active', 'premiumProfile-cme-group']
# ['table-row', 'active', 'premiumProfile-taqa']
# ['table-row', 'active', 'premiumProfile-pernod-ricard']
# ['table-row', 'active', 'premiumProfile-bank-mandiri']
# ['table-row', 'active', 'premiumProfile-femsa']
# ['table-row', 'active', 'premiumProfile-paccar']
# ['table-row', 'active', 'premiumProfile-consolidated-edison']
# ['table-row', 'active', 'premiumProfile-mitsui-fudosan']
# ['table-row', 'active', 'premiumProfile-evergreen-marine-corp-taiwan']
# ['table-row', 'active', 'premiumProfile-komatsu']
# ['table-row', 'active', 'premiumProfile-shaanxi-coal-industry']
# ['table-row', 'active', 'premiumProfile-lenovo-group']
# ['table-row', 'active', 'premiumProfile-fast-retailing']
# ['table-row', 'active', 'premiumProfile-london-stock-exchange']
# ['table-row', 'active', 'premiumProfile-vonovia']
# ['table-row', 'active', 'premiumProfile-aviva']
# ['table-row', 'active', 'premiumProfile-sherwin-williams']
# ['table-row', 'active', 'premiumProfile-fujifilm-holdings']
# ['table-row', 'active', 'premiumProfile-intuit']
# ['table-row', 'active', 'premiumProfile-lam-research']
# ['table-row', 'active', 'premiumProfile-erste-group-bank']
# ['table-row', 'active', 'premiumProfile-lincoln-national']
# ['table-row', 'active', 'premiumProfile-carrier-global']
# ['table-row', 'active', 'premiumProfile-dish-network']
# ['table-row', 'active', 'premiumProfile-china-coal-energy']
# ['table-row', 'active', 'premiumProfile-continental']
# ['table-row', 'active', 'premiumProfile-vtb-bank']
# ['table-row', 'active', 'premiumProfile-murata-manufacturing']
# ['table-row', 'active', 'premiumProfile-larsen-toubro']
# ['table-row', 'active', 'premiumProfile-ally-financial']
# ['table-row', 'active', 'premiumProfile-netease']
# ['table-row', 'active', 'premiumProfile-bank-central-asia']
# ['table-row', 'active', 'premiumProfile-volvo-car']
# ['table-row', 'active', 'premiumProfile-intact-financial']
# ['table-row', 'active', 'premiumProfile-orsted']
# ['table-row', 'active', 'premiumProfile-cummins']
# ['table-row', 'active', 'premiumProfile-williams']
# ['table-row', 'active', 'premiumProfile-capgemini']
# ['table-row', 'active', 'premiumProfile-prologis']
# ['table-row', 'active', 'premiumProfile-thales']
# ['table-row', 'active', 'premiumProfile-bouygues']
# ['table-row', 'active', 'premiumProfile-banorte']
# ['table-row', 'active', 'premiumProfile-ck-asset-holdings']
# ['table-row', 'active', 'premiumProfile-orange']
# ['table-row', 'active', 'premiumProfile-kuehne-nagel-international']
# ['table-row', 'active', 'premiumProfile-bunge']
# ['table-row', 'active', 'premiumProfile-samsung-life-insurance']
# ['table-row', 'active', 'premiumProfile-vmware']
# ['table-row', 'active', 'premiumProfile-albertsons']
# ['table-row', 'active', 'premiumProfile-crrc']
# ['table-row', 'active', 'premiumProfile-cbre-group']
# ['table-row', 'active', 'premiumProfile-toshiba']
# ['table-row', 'active', 'premiumProfile-samsung-ct']
# ['table-row', 'active', 'premiumProfile-infosys']
# ['table-row', 'active', 'premiumProfile-prudential']
# ['table-row', 'active', 'premiumProfile-yankuang-energy-group']
# ['table-row', 'active', 'premiumProfile-canadian-pacific-railway']
# ['table-row', 'active', 'premiumProfile-loews']
# ['table-row', 'active', 'premiumProfile-tokyo-electron']
# ['table-row', 'active', 'premiumProfile-lg-electronics']
# ['table-row', 'active', 'premiumProfile-csl']
# ['table-row', 'active', 'premiumProfile-magna-international']
# ['table-row', 'active', 'premiumProfile-analog-devices']
# ['table-row', 'active', 'premiumProfile-kubota']
# ['table-row', 'active', 'premiumProfile-air-products-chemicals']
# ['table-row', 'active', 'premiumProfile-newmont-mining']
# ['table-row', 'active', 'premiumProfile-te-connectivity']
# ['table-row', 'active', 'premiumProfile-aon']
# ['table-row', 'active', 'premiumProfile-telus']
# ['table-row', 'active', 'premiumProfile-dollar-tree']
# ['table-row', 'active', 'premiumProfile-keycorp']
# ['table-row', 'active', 'premiumProfile-wtw']
# ['table-row', 'active', 'premiumProfile-china-zheshang-bank']
# ['table-row', 'active', 'premiumProfile-wesfarmers']
# ['table-row', 'active', 'premiumProfile-suzuki-motor']
# ['table-row', 'active', 'premiumProfile-best-buy']
# ['table-row', 'active', 'premiumProfile-svb-financial-group']
# ['table-row', 'active', 'premiumProfile-advanced-micro-devices']
# ['table-row', 'active', 'premiumProfile-markel']
# ['table-row', 'active', 'premiumProfile-muyuan-foodstuff']
# ['table-row', 'active', 'premiumProfile-kimberly-clark']
# ['table-row', 'active', 'premiumProfile-swedbank']
# ['table-row', 'active', 'premiumProfile-cognizant']
# ['table-row', 'active', 'premiumProfile-corning']
# ['table-row', 'active', 'premiumProfile-infineon-technologies']
# ['table-row', 'active', 'premiumProfile-citizens-financial-group']
# ['table-row', 'active', 'premiumProfile-devon-energy']
# ['table-row', 'active', 'premiumProfile-asahi-group-holdings']
# ['table-row', 'active', 'premiumProfile-jsw-steel']
# ['table-row', 'active', 'premiumProfile-lumen-technologies']
# ['table-row', 'active', 'premiumProfile-regions-financial']
# ['table-row', 'active', 'premiumProfile-svenska-handelsbanken']
# ['table-row', 'active', 'premiumProfile-raymond-james-financial']
# ['table-row', 'active', 'premiumProfile-byd']
# ['table-row', 'active', 'premiumProfile-illinois-tool-works']
# ['table-row', 'active', 'premiumProfile-pinduoduo']
# ['table-row', 'active', 'premiumProfile-activision-blizzard']
# ['table-row', 'active', 'premiumProfile-liberty-global']
# ['table-row', 'active', 'premiumProfile-colgate-palmolive']
# ['table-row', 'active', 'premiumProfile-sse']
# ['table-row', 'active', 'premiumProfile-nan-ya-plastics']
# ['table-row', 'active', 'premiumProfile-vivendi']
# ['table-row', 'active', 'premiumProfile-baxter-international']
# ['table-row', 'active', 'premiumProfile-fosun-international']
# ['table-row', 'active', 'premiumProfile-weichai-power']
# ['table-row', 'active', 'premiumProfile-fidelity-national-financial']
# ['table-row', 'active', 'premiumProfile-parker-hannifin']
# ['table-row', 'active', 'premiumProfile-vedanta-limited']
# ['table-row', 'active', 'premiumProfile-woori-financial-group']
# ['table-row', 'active', 'premiumProfile-sysco']
# ['table-row', 'active', 'premiumProfile-telstra']
# ['table-row', 'active', 'premiumProfile-credit-suisse-group']
# ['table-row', 'active', 'premiumProfile-rogers-communications']
# ['table-row', 'active', 'premiumProfile-mt-bank']
# ['table-row', 'active', 'premiumProfile-boston-scientific']
# ['table-row', 'active', 'premiumProfile-edison-international']
# ['table-row', 'active', 'premiumProfile-financiere-de-lodet']
# ['table-row', 'active', 'premiumProfile-sumitomo-mitsui-trust']
# ['table-row', 'active', 'premiumProfile-entergy']
# ['table-row', 'active', 'premiumProfile-swisscom']
# ['table-row', 'active', 'premiumProfile-enbw-energie-baden']
# ['table-row', 'active', 'premiumProfile-hikvision']
# ['table-row', 'active', 'premiumProfile-nippon-yusen']
# ['table-row', 'active', 'premiumProfile-stanley-black-decker']
# ['table-row', 'active', 'premiumProfile-oneok']
# ['table-row', 'active', 'premiumProfile-marriott-international']
# ['table-row', 'active', 'premiumProfile-warner-bros-discovery']
# ['table-row', 'active', 'premiumProfile-sf-holding']
# ['table-row', 'active', 'premiumProfile-delta-air-lines']
# ['table-row', 'active', 'premiumProfile-bharat-petroleum']
# ['table-row', 'active', 'premiumProfile-halliburton']
# ['table-row', 'active', 'premiumProfile-metallurgical-corp-of-china']
# ['table-row', 'active', 'premiumProfile-northern-trust']
# ['table-row', 'active', 'premiumProfile-heidelbergcement']
# ['table-row', 'active', 'premiumProfile-china-steel']
# ['table-row', 'active', 'premiumProfile-eversource-energy']
# ['table-row', 'active', 'premiumProfile-sany-heavy-industry']
# ['table-row', 'active', 'premiumProfile-hermes-international']
# ['table-row', 'active', 'premiumProfile-international-paper']
# ['table-row', 'active', 'premiumProfile-koc-holding']
# ['table-row', 'active', 'premiumProfile-nidec']
# ['table-row', 'active', 'premiumProfile-meituan']
# ['table-row', 'active', 'premiumProfile-kotak-mahindra-bank']
# ['table-row', 'active', 'premiumProfile-teck-resources']
# ['table-row', 'active', 'premiumProfile-southwest-airlines']
# ['table-row', 'active', 'premiumProfile-deutsche-boerse']
# ['table-row', 'active', 'premiumProfile-labcorp']
# ['table-row', 'active', 'premiumProfile-china-tower']
# ['table-row', 'active', 'premiumProfile-inpex']
# ['table-row', 'active', 'premiumProfile-coca-cola-european-partners']
# ['table-row', 'active', 'premiumProfile-wuliangye-yibin']
# ['table-row', 'active', 'premiumProfile-shimao-property-holdings']
# ['table-row', 'active', 'premiumProfile-idemitsu-kosan']
# ['table-row', 'active', 'premiumProfile-formosa-petrochemical']
# ['table-row', 'active', 'premiumProfile-crown-castle-international']
# ['table-row', 'active', 'premiumProfile-firstenergy']
# ['table-row', 'active', 'premiumProfile-rongsheng-petrochemical']
# ['table-row', 'active', 'premiumProfile-hindalco-industries']
# ['table-row', 'active', 'premiumProfile-bank-of-hangzhou']
# ['table-row', 'active', 'premiumProfile-renault']
# ['table-row', 'active', 'premiumProfile-international-holding-company']
# ['table-row', 'active', 'premiumProfile-cincinnati-financial']
# ['table-row', 'active', 'premiumProfile-mitsubishi-estate']
# ['table-row', 'active', 'premiumProfile-cleveland-cliffs']
# ['table-row', 'active', 'premiumProfile-grupo-acs']
# ['table-row', 'active', 'premiumProfile-cgn-power']
# ['table-row', 'active', 'premiumProfile-ase-technology-holding']
# ['table-row', 'active', 'premiumProfile-jfe-holdings']
# ['table-row', 'active', 'premiumProfile-dte-energy']
# ['table-row', 'active', 'premiumProfile-china-hongqiao-group']
# ['table-row', 'active', 'premiumProfile-nxp-semiconductors']
# ['table-row', 'active', 'premiumProfile-western-digital']
# ['table-row', 'active', 'premiumProfile-booking']
# ['table-row', 'active', 'premiumProfile-aeon']
# ['table-row', 'active', 'premiumProfile-first-republic-bank']
# ['table-row', 'active', 'premiumProfile-lufax-holding']
# ['table-row', 'active', 'premiumProfile-atlas-copco']
# ['table-row', 'active', 'premiumProfile-fidelity-national-information-fis']
# ['table-row', 'active', 'premiumProfile-mitsubishi-chemical']
# ['table-row', 'active', 'premiumProfile-edp-energias-de-portugal']
# ['table-row', 'active', 'premiumProfile-kyocera']
# ['table-row', 'active', 'premiumProfile-xiamen-cd']
# ['table-row', 'active', 'premiumProfile-autozone']
# ['table-row', 'active', 'premiumProfile-china-taiping-insurance']
# ['table-row', 'active', 'premiumProfile-cenovus-energy']
# ['table-row', 'active', 'premiumProfile-neste']
# ['table-row', 'active', 'premiumProfile-porsche-automobil-holding']
# ['table-row', 'active', 'premiumProfile-hm-hennes-mauritz']
# ['table-row', 'active', 'premiumProfile-relx']
# ['table-row', 'active', 'premiumProfile-pge']
# ['table-row', 'active', 'premiumProfile-republic-services']
# ['table-row', 'active', 'premiumProfile-ross-stores']
# ['table-row', 'active', 'premiumProfile-wec-energy-group']
# ['table-row', 'active', 'premiumProfile-cardinal-health']
# ['table-row', 'active', 'premiumProfile-carmax']
# ['table-row', 'active', 'premiumProfile-china-development-financial']
# ['table-row', 'active', 'premiumProfile-riyad-bank']
# ['table-row', 'active', 'premiumProfile-thomson-reuters']
# ['table-row', 'active', 'premiumProfile-transneft']
# ['table-row', 'active', 'premiumProfile-ferguson']
# ['table-row', 'active', 'premiumProfile-iqvia']
# ['table-row', 'active', 'premiumProfile-hong-kong-exchanges']
# ['table-row', 'active', 'premiumProfile-ppg']
# ['table-row', 'active', 'premiumProfile-legend-holding']
# ['table-row', 'active', 'premiumProfile-ecolab']
# ['table-row', 'active', 'premiumProfile-sinopharm-group']
# ['table-row', 'active', 'premiumProfile-luxshare-precision-industry']
# ['table-row', 'active', 'premiumProfile-seazen-group']
# ['table-row', 'active', 'premiumProfile-global-payments']
# ['table-row', 'active', 'premiumProfile-china-energy-engineering']
# ['table-row', 'active', 'premiumProfile-safran']
# ['table-row', 'active', 'premiumProfile-sp-global']
# ['table-row', 'active', 'premiumProfile-huntington-bank']
# ['table-row', 'active', 'premiumProfile-arch-capital-group']
# ['table-row', 'active', 'premiumProfile-jackson-financial']
# ['table-row', 'active', 'premiumProfile-bank-leumi']
# ['table-row', 'active', 'premiumProfile-trane-technologies']
# ['table-row', 'active', 'premiumProfile-veolia-environnement']
# ['table-row', 'active', 'premiumProfile-oreilly-automotive']
# ['table-row', 'active', 'premiumProfile-biogen-idec']
# ['table-row', 'active', 'premiumProfile-publicis-groupe']
# ['table-row', 'active', 'premiumProfile-hanwha']
# ['table-row', 'active', 'premiumProfile-mosaic']
# ['table-row', 'active', 'premiumProfile-bharti-airtel']
# ['table-row', 'active', 'premiumProfile-daqin-railway']
# ['table-row', 'active', 'premiumProfile-uber']
# ['table-row', 'active', 'premiumProfile-stmicroelectronics']
# ['table-row', 'active', 'premiumProfile-gemdale']
# ['table-row', 'active', 'premiumProfile-ageas']
# ['table-row', 'active', 'premiumProfile-quanta-computer']
# ['table-row', 'active', 'premiumProfile-george-weston']
# ['table-row', 'active', 'premiumProfile-weyerhaeuser']
# ['table-row', 'active', 'premiumProfile-korea-electric-power']
# ['table-row', 'active', 'premiumProfile-fox']
# ['table-row', 'active', 'premiumProfile-mitsubishi-heavy-industries']
# ['table-row', 'active', 'premiumProfile-steel-dynamics']
# ['table-row', 'active', 'premiumProfile-keyence']
# ['table-row', 'active', 'premiumProfile-longi-green-energy-technology']
# ['table-row', 'active', 'premiumProfile-reckitt-benckiser-group']
# ['table-row', 'active', 'premiumProfile-coal-india']
# ['table-row', 'active', 'premiumProfile-aisin-seiki']
# ['table-row', 'active', 'premiumProfile-digital-realty-trust']
# ['table-row', 'active', 'premiumProfile-tata-motors']
# ['table-row', 'active', 'premiumProfile-resona-holdings']
# ['table-row', 'active', 'premiumProfile-simon-property-group']
# ['table-row', 'active', 'premiumProfile-industrial-bank-of-korea']
# ['table-row', 'active', 'premiumProfile-clp-holdings']
# ['table-row', 'active', 'premiumProfile-national-bank-of-kuwait']
# ['table-row', 'active', 'premiumProfile-singtel']
# ['table-row', 'active', 'premiumProfile-coinbase']
# ['table-row', 'active', 'premiumProfile-centerpoint-energy']
# ['table-row', 'active', 'premiumProfile-saudi-arabian-mining']
# ['table-row', 'active', 'premiumProfile-china-cinda-asset-management']
# ['table-row', 'active', 'premiumProfile-asahi-kasei']
# ['table-row', 'active', 'premiumProfile-nec']
# ['table-row', 'active', 'premiumProfile-united-airlines-holdings']
# ['table-row', 'active', 'premiumProfile-mgm-resorts']
# ['table-row', 'active', 'premiumProfile-dsm']
# ['table-row', 'active', 'premiumProfile-telkom-indonesia']
# ['table-row', 'active', 'premiumProfile-pkn-orlen']
# ['table-row', 'active', 'premiumProfile-guotai-junan-securities']
# ['table-row', 'active', 'premiumProfile-norsk-hydro']
# ['table-row', 'active', 'premiumProfile-formosa-plastics']
# ['table-row', 'active', 'premiumProfile-nrg-energy']
# ['table-row', 'active', 'premiumProfile-public-bank']
# ['table-row', 'active', 'premiumProfile-tcl']
# ['table-row', 'active', 'premiumProfile-huatai-securities']
# ['table-row', 'active', 'premiumProfile-kellogg']
# ['table-row', 'active', 'premiumProfile-inner-mongolia-yili']
# ['table-row', 'active', 'premiumProfile-wpp']
# ['table-row', 'active', 'premiumProfile-omnicom-group']
# ['table-row', 'active', 'premiumProfile-sekisui-house']
# ['table-row', 'active', 'premiumProfile-cheniere-energy']
# ['table-row', 'active', 'premiumProfile-sandvik']
# ['table-row', 'active', 'premiumProfile-siam-cement']
# ['table-row', 'active', 'premiumProfile-east-japan-railway']
# ['table-row', 'active', 'premiumProfile-abu-dhabi-commercial']
# ['table-row', 'active', 'premiumProfile-huishang-bank']
# ['table-row', 'active', 'premiumProfile-great-wall-motor']
# ['table-row', 'active', 'premiumProfile-haitong-securities']
# ['table-row', 'active', 'premiumProfile-dongfeng-motor-group']
# ['table-row', 'active', 'premiumProfile-china-reinsurance-group']
# ['table-row', 'active', 'premiumProfile-henderson-land']
# ['table-row', 'active', 'premiumProfile-samsung-sdi']
# ['table-row', 'active', 'premiumProfile-fortis-canada']
# ['table-row', 'active', 'premiumProfile-sk-telecom']
# ['table-row', 'active', 'premiumProfile-hal-trust']
# ['table-row', 'active', 'premiumProfile-banco-btg-pactual']
# ['table-row', 'active', 'premiumProfile-baker-hughes-company']
# ['table-row', 'active', 'premiumProfile-gallagher']
# ['table-row', 'active', 'premiumProfile-everest-re-group']
# ['table-row', 'active', 'premiumProfile-amphenol']
# ['table-row', 'active', 'premiumProfile-american-airlines-group']
# ['table-row', 'active', 'premiumProfile-kla']
# ['table-row', 'active', 'premiumProfile-astellas-pharma']
# ['table-row', 'active', 'premiumProfile-otsuka-holding']
# ['table-row', 'active', 'premiumProfile-china-bohai-bank']
# ['table-row', 'active', 'premiumProfile-kasikornbank']
# ['table-row', 'active', 'premiumProfile-bank-hapoalim']
# ['table-row', 'active', 'premiumProfile-woodside-petroleum']
# ['table-row', 'active', 'premiumProfile-mtr']
# ['table-row', 'active', 'premiumProfile-tatneft']
# ['table-row', 'active', 'premiumProfile-power-finance']
# ['table-row', 'active', 'premiumProfile-zoetis']
# ['table-row', 'active', 'premiumProfile-lonza-group']
# ['table-row', 'active', 'premiumProfile-eiffage']
# ['table-row', 'active', 'premiumProfile-sumitomo-chemical']
# ['table-row', 'active', 'premiumProfile-vertex-pharmaceuticals']
# ['table-row', 'active', 'premiumProfile-constellation-energy']
# ['table-row', 'active', 'premiumProfile-cifi-holdings-group']
# ['table-row', 'active', 'premiumProfile-raiffeisen-bank-international']
# ['table-row', 'active', 'premiumProfile-whirlpool']
# ['table-row', 'active', 'premiumProfile-siemens-energy']
# ['table-row', 'active', 'premiumProfile-westrock']
# ['table-row', 'active', 'premiumProfile-samsung-fire-marine']
# ['table-row', 'active', 'premiumProfile-us-steel']
# ['table-row', 'active', 'premiumProfile-upm-kymmene']
# ['table-row', 'active', 'premiumProfile-formosa-chemicals']
# ['table-row', 'active', 'premiumProfile-sk-innovation']
# ['table-row', 'active', 'premiumProfile-telia']
# ['table-row', 'active', 'premiumProfile-td-holdings']
# ['table-row', 'active', 'premiumProfile-mapfre']
# ['table-row', 'active', 'premiumProfile-hcl-technologies']
# ['table-row', 'active', 'premiumProfile-sumitomo-realty']
# ['table-row', 'active', 'premiumProfile-westlake-chemical']
# ['table-row', 'active', 'premiumProfile-apollo-global-management']
# ['table-row', 'active', 'premiumProfile-united-rentals']
# ['table-row', 'active', 'premiumProfile-diamondback-energy']
# ['table-row', 'active', 'premiumProfile-otis-worldwide']
# ['table-row', 'active', 'premiumProfile-chongqing-rural-bank']
# ['table-row', 'active', 'premiumProfile-ball']
# ['table-row', 'active', 'premiumProfile-stora-enso']
# ['table-row', 'active', 'premiumProfile-yang-ming-marine-transport']
# ['table-row', 'active', 'premiumProfile-phoenix-group-holdings']
# ['table-row', 'active', 'premiumProfile-wipro']
# ['table-row', 'active', 'premiumProfile-power-grid-of-india']
# ['table-row', 'active', 'premiumProfile-absa-group']
# ['table-row', 'active', 'premiumProfile-novolipetsk-steel']
# ['table-row', 'active', 'premiumProfile-sumitomo-electric']
# ['table-row', 'active', 'premiumProfile-st-jamess-place']
# ['table-row', 'active', 'premiumProfile-grasim-industries']
# ['table-row', 'active', 'premiumProfile-segro']
# ['table-row', 'active', 'premiumProfile-mega-financial-holding']
# ['table-row', 'active', 'premiumProfile-zhongsheng-group-holdings']
# ['table-row', 'active', 'premiumProfile-shin-kong-financial']
# ['table-row', 'active', 'premiumProfile-cms-energy']
# ['table-row', 'active', 'premiumProfile-quinenco']
# ['table-row', 'active', 'premiumProfile-evonik']
# ['table-row', 'active', 'premiumProfile-east-money-information']
# ['table-row', 'active', 'premiumProfile-qbe-insurance-group']
# ['table-row', 'active', 'premiumProfile-tenaga-nasional']
# ['table-row', 'active', 'premiumProfile-naver']
# ['table-row', 'active', 'premiumProfile-tdk']
# ['table-row', 'active', 'premiumProfile-nomura']
# ['table-row', 'active', 'premiumProfile-jinke-property-group']
# ['table-row', 'active', 'premiumProfile-tokyo-electric-power']
# ['table-row', 'active', 'premiumProfile-cdw']
# ['table-row', 'active', 'premiumProfile-hershey']
# ['table-row', 'active', 'premiumProfile-itc']
# ['table-row', 'active', 'premiumProfile-pgnig-group']
# ['table-row', 'active', 'premiumProfile-mtn-group']
# ['table-row', 'active', 'premiumProfile-compass-group']
# ['table-row', 'active', 'premiumProfile-wr-berkley']
# ['table-row', 'active', 'premiumProfile-moodys']
# ...
# ['table-row', 'active', 'premiumProfile-mercuries-associates']
# ['table-row', 'active', 'premiumProfile-beigene']
# ['table-row', 'active', 'premiumProfile-pan-pacific-international-holdings']
# ['table-row', 'active', 'premiumProfile-exor']
# ['table-row', 'active', 'premiumProfile-daito-trust-construction']
# ['table-row', 'active', 'premiumProfile-synnex-tech-intl']
# ['table-row', 'active', 'premiumProfile-adani-total-gas']
# ['table-row', 'active', 'premiumProfile-wuxi-biologics']
# ['table-row', 'active', 'premiumProfile-johnson-matthey']
# ['table-row', 'active', 'premiumProfile-bayan-resources']
# ['table-row', 'active', 'premiumProfile-burlington-stores']
# ['table-row', 'active', 'premiumProfile-credito-emiliano']
# ['table-row', 'active', 'premiumProfile-alfresa-holdings']
# ['table-row', 'active', 'premiumProfile-bandai-namco-holdings']
# ['table-row', 'active', 'premiumProfile-faw-jiefang-group']
# ['table-row', 'active', 'premiumProfile-constellation-software']
# ['table-row', 'active', 'premiumProfile-bajaj-auto']
# ['table-row', 'active', 'premiumProfile-chewy']
# ['table-row', 'active', 'premiumProfile-shandong-hualu-hengsheng-chemical']
# ['table-row', 'active', 'premiumProfile-avenue-supermarts']
# ['table-row', 'active', 'premiumProfile-lindt-sprungli']
# ['table-row', 'active', 'premiumProfile-skf-group']
# ['table-row', 'active', 'premiumProfile-iyo-bank']
# ['table-row', 'active', 'premiumProfile-juroku-financial-group']
# ['table-row', 'active', 'premiumProfile-akamai-technologies']
# ['table-row', 'active', 'premiumProfile-ems-chemie-holding']
# ['table-row', 'active', 'premiumProfile-medical-properties-trust']
# ['table-row', 'active', 'premiumProfile-taiwan-business-bank']
# ['table-row', 'active', 'premiumProfile-zhejiang-chint-electrics']
# ['table-row', 'active', 'premiumProfile-newell-brands']
# ['table-row', 'active', 'premiumProfile-first-pacific']
# ['table-row', 'active', 'premiumProfile-bank-of-jiujiang']
# ['table-row', 'active', 'premiumProfile-dgb-financial-group']
# ['table-row', 'active', 'premiumProfile-power-assets-holdings']
# ['table-row', 'active', 'premiumProfile-xinyi-glass-holdings']
# ['table-row', 'active', 'premiumProfile-toll-brothers']
# ['table-row', 'active', 'premiumProfile-pik-group']
# ['table-row', 'active', 'premiumProfile-foot-locker']
# ['table-row', 'active', 'premiumProfile-bank-of-suzhou']
# ['table-row', 'active', 'premiumProfile-hyundai-engineering']
# ['table-row', 'active', 'premiumProfile-american-equity-investment']
# ['table-row', 'active', 'premiumProfile-advantest']
# ['table-row', 'active', 'premiumProfile-avnet']
# ['table-row', 'active', 'premiumProfile-hyakugo-bank']
# ['table-row', 'active', 'premiumProfile-lucid-motors']
# ['table-row', 'active', 'premiumProfile-cspc-pharmaceutical-group']
# ['table-row', 'active', 'premiumProfile-atos']
# ['table-row', 'active', 'premiumProfile-manpower']
# ['table-row', 'active', 'premiumProfile-hotai-motor']
# ['table-row', 'active', 'premiumProfile-smoore-international-holdings']
# ['table-row', 'active', 'premiumProfile-clorox']
# ['table-row', 'active', 'premiumProfile-dcc']
# ['table-row', 'active', 'premiumProfile-gjensidige-forsikring']
# ['table-row', 'active', 'premiumProfile-ford-otosan']
# ['table-row', 'active', 'premiumProfile-bank-of-queensland']
# ['table-row', 'active', 'premiumProfile-fortune-brands-home-security']
# ['table-row', 'active', 'premiumProfile-lear']
# ['table-row', 'active', 'premiumProfile-service-corp-intl']
# ['table-row', 'active', 'premiumProfile-korea-zinc']
# ['table-row', 'active', 'premiumProfile-qingdao-rural-commercial-bank']
# ['table-row', 'active', 'premiumProfile-tosoh']
# ['table-row', 'active', 'premiumProfile-doordash']
# ['table-row', 'active', 'premiumProfile-cloudflare']
# ['table-row', 'active', 'premiumProfile-jointown-pharmaceutical-group']
# ['table-row', 'active', 'premiumProfile-showa-denko']
# ['table-row', 'active', 'premiumProfile-kawasaki-heavy-industries']
# ['table-row', 'active', 'premiumProfile-deutsche-pfandbriefbank']
# ['table-row', 'active', 'premiumProfile-nio']
# ['table-row', 'active', 'premiumProfile-ultrapar-participacoes']
# ['table-row', 'active', 'premiumProfile-american-national-group']
# ['table-row', 'active', 'premiumProfile-ogaki-kyoritsu-bank']
# ['table-row', 'active', 'premiumProfile-bendigo-adelaide-bank']
# ['table-row', 'active', 'premiumProfile-tongling-nonferrous-metals']
# ['table-row', 'active', 'premiumProfile-electric-power-development']
# ['table-row', 'active', 'premiumProfile-salzgitter']
# ['table-row', 'active', 'premiumProfile-suzuken']
# ['table-row', 'active', 'premiumProfile-shiga-bank']
# ['table-row', 'active', 'premiumProfile-sartorius']
# ['table-row', 'active', 'premiumProfile-tsim-sha-tsui-properties']
# ['table-row', 'active', 'premiumProfile-qilu-bank']
# ['table-row', 'active', 'premiumProfile-horizon-therapeutics-public-limited-company']
# ['table-row', 'active', 'premiumProfile-prysmian']
# ['table-row', 'active', 'premiumProfile-crescent-point-energy']
# ['table-row', 'active', 'premiumProfile-info-edge-india']
# ['table-row', 'active', 'premiumProfile-finecobank']
# ['table-row', 'active', 'premiumProfile-hubei-biocause-pharmaceutical']
# ['table-row', 'active', 'premiumProfile-icon']
# ['table-row', 'active', 'premiumProfile-yunnan-copper-co-ltd']
# ['table-row', 'active', 'premiumProfile-booz-allen-hamilton-holding']
# ['table-row', 'active', 'premiumProfile-red-electrica']
# ['table-row', 'active', 'premiumProfile-senshu-ikeda-holdings']
# ['table-row', 'active', 'premiumProfile-banca-popolare-di-sondrio']
# ['table-row', 'active', 'premiumProfile-zhejiang-expressway-co-ltd']
# ['table-row', 'active', 'premiumProfile-wsp']
# ['table-row', 'active', 'premiumProfile-lpl-financial-holdings']
# ['table-row', 'active', 'premiumProfile-mid-america-apartment-communities']
# ['table-row', 'active', 'premiumProfile-titan']
# ['table-row', 'active', 'premiumProfile-beijing-oriental-yuhong-waterproof-technology']
# ['table-row', 'active', 'premiumProfile-sistema']
# ['table-row', 'active', 'premiumProfile-wayfair']
# ['table-row', 'active', 'premiumProfile-zscaler']
# ['table-row', 'active', 'premiumProfile-dangote-cement']
# ['table-row', 'active', 'premiumProfile-ricoh']
# ['table-row', 'active', 'premiumProfile-trade-desk']
# ['table-row', 'active', 'premiumProfile-chr-hansen-holding']
# ['table-row', 'active', 'premiumProfile-jd-sports-fashion']
# ['table-row', 'active', 'premiumProfile-aeroports-de-paris']
# ['table-row', 'active', 'premiumProfile-banque-cantonale-vaudoise']
# ['table-row', 'active', 'premiumProfile-amadeus-it-group']
# ['table-row', 'active', 'premiumProfile-bank-of-lanzhou']
# ['table-row', 'active', 'premiumProfile-digital-china-group']
# ['table-row', 'active', 'premiumProfile-korean-air']
# ['table-row', 'active', 'premiumProfile-san-in-godo-bank']
# ['table-row', 'active', 'premiumProfile-cpfl-energia']
# ['table-row', 'active', 'premiumProfile-airports-of-thailand']
# ['table-row', 'active', 'premiumProfile-nanto-bank']
# ['table-row', 'active', 'premiumProfile-toho-bank']
# ['table-row', 'active', 'premiumProfile-veeva-systems']
# ['table-row', 'active', 'premiumProfile-aier-eye-hospital-group']
# ['table-row', 'active', 'premiumProfile-keiyo-bank']
# ['table-row', 'active', 'premiumProfile-abrdn']
# ['table-row', 'active', 'premiumProfile-kyndryl-holdings']
# ['table-row', 'active', 'premiumProfile-qurate-retail-group']
# ['table-row', 'active', 'premiumProfile-cosco-shipping-development']
# ['table-row', 'active', 'premiumProfile-huaibei-mining-holdings']
# ['table-row', 'active', 'premiumProfile-inventec']
# ['table-row', 'active', 'premiumProfile-hanwa']
# ['table-row', 'active', 'premiumProfile-pt-saratoga-investama-sedaya']
# ['table-row', 'active', 'premiumProfile-saputo']
# ['table-row', 'active', 'premiumProfile-shimizu']
# ['table-row', 'active', 'premiumProfile-e-l-financial']
# ['table-row', 'active', 'premiumProfile-basler-kantonalbank']
# ['table-row', 'active', 'premiumProfile-snap-on']
# ['table-row', 'active', 'premiumProfile-luzerner-kantonalbank']
# ['table-row', 'active', 'premiumProfile-zhangzhou-pientzehuang-pharmaceutical']
# ['table-row', 'active', 'premiumProfile-kinnevik']
# ['table-row', 'active', 'premiumProfile-vietnam-technological-commercial-joint-stock-bank']
# ['table-row', 'active', 'premiumProfile-fibi-holdings']
# ['table-row', 'active', 'premiumProfile-wesco-international']
# ['table-row', 'active', 'premiumProfile-yunnan-yuntianhua']
# ['table-row', 'active', 'premiumProfile-sitc-international-holdings']
# ['table-row', 'active', 'premiumProfile-anhui-water-resources-development']
# ['table-row', 'active', 'premiumProfile-tokyo-kiraboshi-financial-group']
# ['table-row', 'active', 'premiumProfile-tenneco']
# ['table-row', 'active', 'premiumProfile-pacwest-bancorp']
# ['table-row', 'active', 'premiumProfile-bank-of-gansu']
# ['table-row', 'active', 'premiumProfile-barry-callebaut']
# ['table-row', 'active', 'premiumProfile-grupa-lotos']
# ['table-row', 'active', 'premiumProfile-yunnan-energy-new-material']
# ['table-row', 'active', 'premiumProfile-sca']
# ['table-row', 'active', 'premiumProfile-acwa-power']
# ['table-row', 'active', 'premiumProfile-ff']
# ['table-row', 'active', 'premiumProfile-pennymac-financial-services']
# ['table-row', 'active', 'premiumProfile-aareal-bank']
# ['table-row', 'active', 'premiumProfile-essex-property-trust']
# ['table-row', 'active', 'premiumProfile-nanjing-iron-steel']
# ['table-row', 'active', 'premiumProfile-samsung-sds']
# ['table-row', 'active', 'premiumProfile-aozora-bank']
# ['table-row', 'active', 'premiumProfile-electrolux-group']
# ['table-row', 'active', 'premiumProfile-azrieli-group']
# ['table-row', 'active', 'premiumProfile-brown-brown']
# ['table-row', 'active', 'premiumProfile-times-property-holdings']
# ['table-row', 'active', 'premiumProfile-gold-fields']
# ['table-row', 'active', 'premiumProfile-commerce-bancshares']
# ['table-row', 'active', 'premiumProfile-tmb-bank']
# ['table-row', 'active', 'premiumProfile-china-aviation-oil']
# ['table-row', 'active', 'premiumProfile-nippon-steel-trading']
# ['table-row', 'active', 'premiumProfile-webster-financial']
# ['table-row', 'active', 'premiumProfile-novatek-microelectronics']
# ['table-row', 'active', 'premiumProfile-persimmon']
# ['table-row', 'active', 'premiumProfile-seagen']
# ['table-row', 'active', 'premiumProfile-commercial-metals']
# ['table-row', 'active', 'premiumProfile-mongodb']
# ['table-row', 'active', 'premiumProfile-bank-of-xian']
# ['table-row', 'active', 'premiumProfile-grifols']
# ['table-row', 'active', 'premiumProfile-murphy-usa']
# ['table-row', 'active', 'premiumProfile-cencosud']
# ['table-row', 'active', 'premiumProfile-ares-management']
# ['table-row', 'active', 'premiumProfile-kiyo-bank']
# ['table-row', 'active', 'premiumProfile-shandong-iron-and-steel']
# ['table-row', 'active', 'premiumProfile-parkland']
# ['table-row', 'active', 'premiumProfile-central-bank-of-india']
# ['table-row', 'active', 'premiumProfile-galaxy-entertainment']
# ['table-row', 'active', 'premiumProfile-teledyne-technologies']
# ['table-row', 'active', 'premiumProfile-dexus']
# ['table-row', 'active', 'premiumProfile-palantir-technologies']
# ['table-row', 'active', 'premiumProfile-rothschild-co']
# ['table-row', 'active', 'premiumProfile-wintrust-financial']
# ['table-row', 'active', 'premiumProfile', 'premiumProfile-costar-group']
# ['table-row', 'active', 'premiumProfile-banque-centrale-populaire']
# ['table-row', 'active', 'premiumProfile-mr-cooper-group']
# ['table-row', 'active', 'premiumProfile-xiamen-xinde-co-ltd-class-a']
# ['table-row', 'active', 'premiumProfile-ayala']
# ['table-row', 'active', 'premiumProfile-shanghai-fosun-pharmaceutical-group']
# ['table-row', 'active', 'premiumProfile-shenzhen-inovance-technology']
# ['table-row', 'active', 'premiumProfile-genmab']
# ['table-row', 'active', 'premiumProfile-ansys']
# ['table-row', 'active', 'premiumProfile-tmx-group']
# ['table-row', 'active', 'premiumProfile-gap']
# ['table-row', 'active', 'premiumProfile-hyakujushi-bank']
# ['table-row', 'active', 'premiumProfile-asm-international']
# ['table-row', 'active', 'premiumProfile-tokyu-fudosan']
# ['table-row', 'active', 'premiumProfile-albemarle']
# ['table-row', 'active', 'premiumProfile-bradespar']
# ['table-row', 'active', 'premiumProfile-aristocrat-leisure']
# ['table-row', 'active', 'premiumProfile-hainan-airlines-holding']
# ['table-row', 'active', 'premiumProfile-metropolitan-bank-trust']
# ['table-row', 'active', 'premiumProfile-robert-half-international']
# ['table-row', 'active', 'premiumProfile-shanghai-yuyuan-tourist-mart']
# ['table-row', 'active', 'premiumProfile-bread-financial-holdings']
# ['table-row', 'active', 'premiumProfile-healthpeak-properties']
# ['table-row', 'active', 'premiumProfile-steris']
# ['table-row', 'active', 'premiumProfile-yamada-denki']
# ['table-row', 'active', 'premiumProfile-xpo-logistics']
# ['table-row', 'active', 'premiumProfile-hera']
# ['table-row', 'active', 'premiumProfile-intco-medical-technology']
# ['table-row', 'active', 'premiumProfile-adnoc-drilling']
# ['table-row', 'active', 'premiumProfile-hokkoku-financial-holdings']
# ['table-row', 'active', 'premiumProfile-shenzhou-international-group-holdings']
# ['table-row', 'active', 'premiumProfile-far-eastern-new-century']
# ['table-row', 'active', 'premiumProfile-farfetch']
# ['table-row', 'active', 'premiumProfile-huali-industrial-group']
# ['table-row', 'active', 'premiumProfile-jindal-steel-power']
# ['table-row', 'active', 'premiumProfile-mashreq-bank']
# ['table-row', 'active', 'premiumProfile-zall-smart-commerce-group']
# ['table-row', 'active', 'premiumProfile-fcc']
# ['table-row', 'active', 'premiumProfile-veon']
# ['table-row', 'active', 'premiumProfile-avichina-industry-technology-co-ltd-class-h']
# ['table-row', 'active', 'premiumProfile-masco']
# ['table-row', 'active', 'premiumProfile-weihai-city-commercial-bank']
# ['table-row', 'active', 'premiumProfile-cadence-bank']
# ['table-row', 'active', 'premiumProfile-yamato-holdings']
# ['table-row', 'active', 'premiumProfile-musashino-bank']
# ['table-row', 'active', 'premiumProfile-pinnacle-bank']
# ['table-row', 'active', 'premiumProfile-jinshang-bank']
# ['table-row', 'active', 'premiumProfile-seiko-epson']
# ['table-row', 'active', 'premiumProfile-ampol']
# ['table-row', 'active', 'premiumProfile-jb-financial-group']
# ['table-row', 'active', 'premiumProfile-tapestry']
# ['table-row', 'active', 'premiumProfile-logitech-international']
# ['table-row', 'active', 'premiumProfile-fertiglobe']
# ['table-row', 'active', 'premiumProfile-wt-microelectronics']
# ['table-row', 'active', 'premiumProfile-group-1-automotive']
# ['table-row', 'active', 'premiumProfile-unity-software']
# ['table-row', 'active', 'premiumProfile-china-petroleum-engineering']
# ['table-row', 'active', 'premiumProfile-li-auto']
# ['table-row', 'active', 'premiumProfile-swedish-match']
# ['table-row', 'active', 'premiumProfile-twilio']
# ['table-row', 'active', 'premiumProfile-whitecap-resources']
# ['table-row', 'active', 'premiumProfile-efg-international']
# ['table-row', 'active', 'premiumProfile-grandjoy-holdings-group']
# ['table-row', 'active', 'premiumProfile-kloeckner-co']
# ['table-row', 'active', 'premiumProfile-match-group']
# ['table-row', 'active', 'premiumProfile-onex']
# ['table-row', 'active', 'premiumProfile-wingtech-technology']
# ['table-row', 'active', 'premiumProfile-aperam']
# ['table-row', 'active', 'premiumProfile-shenzhen-feima-international-supply-chain']
# ['table-row', 'active', 'premiumProfile-nmdc']
# ['table-row', 'active', 'premiumProfile-sichuan-changhong-electric']
# ['table-row', 'active', 'premiumProfile-satellite-chemical']
# ['table-row', 'active', 'premiumProfile-sun-communities']
# <ipython-input-3-5f62a6746d62>:44: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("companiesForbes.xls")    #probabilmente formato migliore per salvarlo

# %% [markdown]
# # **Wikipedia.org**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from csv import writer

df = pd.DataFrame(columns=['Name', 'Industry','Sector',  'Headquarters', 'Founded', 'Notes'])

#1035 elementi totali con questi 3 link
links = ['https://en.wikipedia.org/wiki/List_of_companies_of_Italy', 'https://en.wikipedia.org/wiki/List_of_companies_of_Germany', 'https://en.wikipedia.org/wiki/List_of_companies_of_Sweden']

for link in links:
  data = requests.get(link).text
  print(link)

  soup = BeautifulSoup(data, 'html.parser')

  print('Classes of each table:')
  for table in soup.find_all("table", {"class": "wikitable"}):
      print(table.get('class'))

  tables = soup.find_all('table')

  for row in tables[1].tbody.find_all('tr'):    #scorre le righe della seconda tabella
      
      columns = row.find_all('td')    #scorre i dati della tabella
    
      if(columns != []):
          name = columns[0].text.strip()
          industry = columns[1].text.strip()
          sector = columns[2].text.strip()
          if(sector == "-"):
            sector = ""
          hq = columns[3].text.strip()
          if(hq == "?"):
            hq = ""
          founded = columns[4].text.strip()
          if(len(founded)>4):
            founded = founded[:4]
          if(founded == "?"):
            founded = ""
          notes = columns[5].text.strip()

          df = df.append({'Name': name, 'Industry' : industry, 'Sector': sector, 'Headquarters': hq, 'Founded': founded, 'Notes': notes}, ignore_index=True)

df.head
df.to_excel("companiesWiki.xls")
# Out:
# https://en.wikipedia.org/wiki/List_of_companies_of_Italy
# Classes of each table:
# ['wikitable', 'sortable']
# ['wikitable', 'sortable']
# https://en.wikipedia.org/wiki/List_of_companies_of_Germany
# Classes of each table:
# ['wikitable', 'sortable']
# ['wikitable', 'sortable']
# https://en.wikipedia.org/wiki/List_of_companies_of_Sweden
# Classes of each table:
# ['wikitable', 'sortable']
# ['wikitable', 'sortable']
# <ipython-input-4-76a74fb3f226>:46: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("companiesWiki.xls")

# %% [markdown]
# # **Disfold.com**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from csv import writer

# Defining of the dataframe
df = pd.DataFrame(columns=['Name', 'MarketCap', 'Stock', 'Country', 'Sector', 'Industry'])

i = 1 #variabile da incrementare per scorrere le pagine dell'url del sito

#scorriamo le 20 pagine del sito 
while i < 21:
  j = str(i)    #la variabile va convertita in stringa per essere passata nell'url
  link = 'https://disfold.com/world/companies/?page='+j
  print(link)
  
  data = requests.get(link).text

  soup = BeautifulSoup(data, 'html.parser')

  print('Classes of each table:')
  for table in soup.find_all('table'):
      print(table.get('class'))

  tables = soup.find_all('table')
  
  for row in table.tbody.find_all('tr'):    #scorre le righe

      columns = row.find_all('td')    #scorre i dati della tabella
    
      if(columns != []):
          name = columns[1].text.strip()
          #alcuni elementi hanno un figlio 'p' che indica una data, quindi nel caso ci fosse vogliamo escluderlo e prendere solo il primo elemento del <td>
          if(columns[2].find('p')):
            mcap = columns[2].contents[0].strip()
          else:
            mcap = columns[2].text.strip()
          stock = columns[3].text.strip()
          country = columns[4].text.strip()
          sector = columns[5].text.strip()
          industry = columns[6].text.strip()

          df = df.append({'Name': name, 'MarketCap' : mcap, 'Stock': stock, 'Country': country, 'Sector': sector, 'Industry': industry}, ignore_index=True)

  del link
  i = i+1

df.head(None)   #stampa la tabella [senza (None) stampa solo le prime 5 righe]

df.to_excel("companiesDisfold.xls")
# Out:
# https://disfold.com/world/companies/?page=1
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=2
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=3
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=4
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=5
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=6
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=7
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=8
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=9
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=10
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=11
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=12
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=13
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=14
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=15
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=16
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=17
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=18
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=19
# Classes of each table:
# ['striped', 'responsive-table']
# https://disfold.com/world/companies/?page=20
# Classes of each table:
# ['striped', 'responsive-table']
# <ipython-input-5-e6d0b3d7126f>:50: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("companiesDisfold.xls")
